# %%
#import pandas library
import pandas as pd

# %%
#creating data frame
df=pd.DataFrame([[10,12,14,16],[11,18,15,21],[12,13,14,15]],
columns=["CD","DBMS","DSS","CAO",])

# %%
df
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    12   14   16
# 1  11    18   15   21
# 2  12    13   14   15

# %%
df.shape
# Out:
# (3, 5)

# %%
df.size
# Out:
# 15

# %%
df.ndim
# Out:
# 2

# %%
df.loc[len(df)]=[5,6,7,8]

# %%
df
# Out:
#    CD  DBMS  DSS  CAO
# 0  10    12   14   16
# 1  11    18   15   21
# 2  12    13   14   15
# 3   5     6    7    8

# %%
df["DM"]=[12,13,14,15]

# %%
df
# Out:
#    CD  DBMS  DSS  CAO  DM
# 0  10    12   14   16  12
# 1  11    18   15   21  13
# 2  12    13   14   15  14
# 3   5     6    7    8  15

# %%
df4=df3.drop(index=[1])

# %%
df4
# Out:
#    CD  DBMS  DSS  CAO
# 0   5     6    7    8

# %%
#finding mean of DSS
print("Mean  of DSS:",df4["DSS"].mean())
# Out:
# Mean  of DSS: 7.0

# %%
#finding mean of DSS
print("Mode  of DSS:",df4["DSS"].mode())
# Out:
# Mode  of DSS: 0    7
# Name: DSS, dtype: int64

# %%
#finding mean of DSS
print("Median  of DSS:",df4["DSS"].median())
# Out:
# Median  of DSS: 7.0

# %%
#creating  name list
Name=["Aastha","Ziya","Harshal","Yash"]
Name
# Out:
# ['Aastha', 'Ziya', 'Harshal', 'Yash']

# %%
#creating a series
Roll_list=pd.Series(Name,index=[1,2,3,4])
print(Roll_list)
# Out:
# 1     Aastha
# 2       Ziya
# 3    Harshal
# 4       Yash
# dtype: object
