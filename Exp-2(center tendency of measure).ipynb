# %%
age=[22,21,20,20,21,22,22,21,20,22]

# %%
print(age)
# Out:
# [22, 21, 20, 20, 21, 22, 22, 21, 20, 22]

# %%
age
# Out:
# [22, 21, 20, 20, 21, 22, 22, 21, 20, 22]

# %%
import statistics

# %%
a=statistics.mean(age)

# %%
a
# Out:
# 21.1

# %%
b=statistics.median(age)

# %%
b
# Out:
# 21.0

# %%
c=statistics.mode(age)

# %%
c
# Out:
# 22

# %%
 import numpy as np
x=np.array([1,2,3,4,5,6,7,2,6,2,1,4,2,2,6])

# %%
x
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 2, 6, 2, 1, 4, 2, 2, 6])

# %%
print(np.mean(x))
# Out:
# 3.533333333333333

# %%
print(stats.mode(x))
# Out:
# ModeResult(mode=np.int64(2), count=np.int64(5))

# %%
print(np.median(x))
# Out:
# 3.0

# %%
from scipy import stats

# %%
print(stats.mode(x))
# Out:
# ModeResult(mode=np.int64(2), count=np.int64(5))

# %%
print(np.std(x))
# Out:
# 1.9618585292749546

# %%
print(np.var(x))
# Out:
# 3.8488888888888884
